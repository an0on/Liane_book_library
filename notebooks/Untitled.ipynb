# %%
import pandas as pd
import matplotlib.pyplot as plt



from connect import connection_string
connection_string
# Out:
# 1. Existiert der Ordner 'src'? : False
# 2. Existiert 'connect.py' dort?: False
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 34
#      30
#      31 # Jetzt kannst du connect importieren
#      32
#      33
# ---> 34 from connect import connection_string
#      35 connection_string
#
# ModuleNotFoundError: No module named 'connect'
